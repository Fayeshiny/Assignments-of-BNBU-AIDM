# %% [markdown]
# ### Task 1 (*40 points*)
#
# Please work on the dataset `imdb_top_1000.csv` in the data folder. Imagining that the user is currently watching the movie **`Inception`**, your task is to build a 'next watching list' containing 10 movies.
#
# -  **List 1** (*20 pionts*):
#
#     Creat and print a recommendation list according to the overview of the movies.
#
#
# -  **List 2** (*20 pionts*):
#
#     Creat and print a recommendation list according to the meta data (including movie genre, stars and directors) of the movies.
#
#
# - **List 3** (*Optional*):
#
#     Creat and print a recommendation list by combining the two results above. For example, you could assign a weight for each of the simlarity scores(i.e.,w and 1-w) to get a final simlarity score, based on which you generate the final recommendation list.
#
# *Suggestion for feature extraction: TfidfVectorizer*

# %%
#libraries you may need (add more if needed)
import numpy as np
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

### YOUR CODE HERE


###
